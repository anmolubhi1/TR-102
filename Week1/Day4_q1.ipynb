# %% [markdown]
# <a href="https://colab.research.google.com/github/anmolubhi1/TR-102/blob/main/Day4_q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv('Day-4.csv')

# %%
df.head()
# Out:
#    S.no     x     y     z
# 0     1  74.0   8.0  65.0
# 1     2  53.0   NaN  30.0
# 2     3  46.0  55.0   NaN
# 3     4   NaN   NaN  90.0
# 4     5  80.0  93.0  22.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   S.no    15 non-null     int64
#  1   x       12 non-null     float64
#  2   y       8 non-null      float64
#  3   z       9 non-null      float64
# dtypes: float64(3), int64(1)
# memory usage: 612.0 bytes

# %%
df.isnull()
# Out:
#      S.no      x      y      z
# 0   False  False  False  False
# 1   False  False   True  False
# 2   False  False  False   True
# 3   False   True   True  False
# 4   False  False  False  False
# 5   False  False   True   True
# 6   False  False  False  False
# 7   False   True   True  False
# 8   False  False  False   True
# 9   False  False   True  False
# 10  False  False  False   True
# 11  False   True   True  False
# 12  False  False  False   True
# 13  False  False   True  False
# 14  False  False  False   True

# %%
df.isnull().sum()
# Out:
# S.no    0
# x       3
# y       7
# z       6
# dtype: int64
